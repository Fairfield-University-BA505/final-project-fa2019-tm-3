# %% [markdown]
# # Group project Python

# %% [markdown]
# Spotify reached out to our company TM3 for assisance with their target ad campaign. Their sponsors do not believe their ads are being appropriately targeted. Spotify is looking for better ways to target adolcecents based on the type of music they listen to.
#
# Today, we are presenting to you, the management team at Spotify, with our findings. Your management team hopes that TM3's findings can help them better market their sponsor's ads in the upcoming year.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
# try

# %%
#Import original dataset-Research
research = pd.read_csv("research.csv")
research.head()
# Out:
#    Music  Slow songs or fast songs  Pop  Rock  Hiphop, Rap  Latino  \
# 0      5                         3    5     5            1       1
# 1      4                         4    3     5            1       2
# 2      5                         5    3     5            1       5
# 3      5                         3    5     3            5       4
# 4      5                         3    2     5            4       3
#
#    Techno, Trance  Comedy  Romantic  Sci-fi  ...  Folk  Country  \
# 0               1       5         4       4  ...     1        2
# 1               1       4         3       4  ...     1        1
# 2               1       4         2       4  ...     2        3
# 3               2       5         2       3  ...     3        2
# 4               1       5         2       3  ...     3        2
#
#    Classical music  Musical  Metal or Hardrock  Punk  Opera  Movies Horror  \
# 0                2        1                  1     1      1       5      4
# 1                1        2                  4     4      1       5      2
# 2                4        5                  3     4      3       5      3
# 3                4        3                  1     2      2       5      4
# 4                3        3                  5     3      3       5      5
#
#   Thriller
# 0        2
# 1        2
# 2        4
# 3        4
# 4        5
#
# [5 rows x 37 columns]

# %%
#Make copy of original dataset to make changes
research2 = research.copy()
research2.head()
# Out:
#    Music  Slow songs or fast songs  Pop  Rock  Hiphop, Rap  Latino  \
# 0      5                         3    5     5            1       1
# 1      4                         4    3     5            1       2
# 2      5                         5    3     5            1       5
# 3      5                         3    5     3            5       4
# 4      5                         3    2     5            4       3
#
#    Techno, Trance  Comedy  Romantic  Sci-fi  ...  Folk  Country  \
# 0               1       5         4       4  ...     1        2
# 1               1       4         3       4  ...     1        1
# 2               1       4         2       4  ...     2        3
# 3               2       5         2       3  ...     3        2
# 4               1       5         2       3  ...     3        2
#
#    Classical music  Musical  Metal or Hardrock  Punk  Opera  Movies Horror  \
# 0                2        1                  1     1      1       5      4
# 1                1        2                  4     4      1       5      2
# 2                4        5                  3     4      3       5      3
# 3                4        3                  1     2      2       5      4
# 4                3        3                  5     3      3       5      5
#
#   Thriller
# 0        2
# 1        2
# 2        4
# 3        4
# 4        5
#
# [5 rows x 37 columns]

# %%
#Delete out extra columns not pertaining to research questions.
research2.drop(research2.columns[21:], axis=1, inplace=True)
research2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-9fc0ea7f03fd> in <module>
#       1 #Delete out extra columns not pertaining to research questions.
# ----> 2 research2.drop(research2.columns[21:], axis=1, inplace=True)
#       3 research2.head()
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
# Changing value names from int to object
# 1 & 2: dislike
# 3: netural
# 4 & 5: like

# Pop
research2['Pop']=research2['Pop'].astype(str)
# research2.dtypes --> make sure type was changed correctly
Pop_dict={'1': 'dislike', '2':'dislike', '3':'neutral', '4':'like', '5':'like'}
research2['Pop']=research2['Pop'].map(Pop_dict)


# Rock
research2['Rock']=research2['Rock'].astype(str)
# research2.dtypes --> make sure type was changed correctly
Rock_dict={'1': 'dislike', '2':'dislike', '3':'neutral', '4':'like', '5':'like'}
research2['Rock']=research2['Rock'].map(Rock_dict)


# Hiphop,Rap
research2['Hiphop,Rap']=research2['Hiphop,Rap'].astype(str)
# research2.dtypes --> make sure type was changed correctly
Hiphop_dict={'1': 'dislike', '2':'dislike', '3':'neutral', '4':'like', '5':'like'}
research2['Hiphop,Rap']=research2['Hiphop,Rap'].map(Hiphop_dict)


# Latino
research2['Latino']=research2['Latino'].astype(str)
# research2.dtypes --> make sure type was changed correctly
Latino_dict={'1': 'dislike', '2':'dislike', '3':'neutral', '4':'like', '5':'like'}
research2['Latino']=research2['Latino'].map(Latino_dict)


# Techno,Trance
research2['Techno,Trance']=research2['Techno,Trance'].astype(str)
# research2.dtypes --> make sure type was changed correctly
Techno_dict={'1': 'dislike', '2':'dislike', '3':'neutral', '4':'like', '5':'like'}
research2['Techno,Trance']=research2['Techno,Trance'].map(Techno_dict)
research2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hiphop,Rap'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-8eee8a575e5c> in <module>
#      19
#      20 # Hiphop,Rap
# ---> 21 research2['Hiphop,Rap']=research2['Hiphop,Rap'].astype(str)
#      22 # research2.dtypes --> make sure type was changed correctly
#      23 Hiphop_dict={'1': 'dislike', '2':'dislike', '3':'neutral', '4':'like', '5':'like'}
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /opt/tljh/user/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hiphop,Rap'

# %%
#Gender and music preferences
#Gender and Pop
gender_v_pop =research2.groupby(['Pop', 'Gender'])['Pop'].count().unstack('Gender').plot(kind='bar', color=["pink","blue"])

# adding labels
plt.title('Popularity of Pop music')
plt.ylabel('Number of people')
plt.xlabel('Preferences')
plt.xticks(rotation='horizontal')

gender_v_pop

# %%
#Gender and music preferences


#Gender and Rock

# %%
#Gender and music preferences
#Gender and Hip Hop/Rap

# %%
#Gender and music preferences
#Gender and Latin

# %%
#Gender and music preferences
#Gender and Techno/Trance(EDM)

# %%
#Music Generes by gender
#Pie Chart: https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html#sphx-glr-gallery-pie-and-polar-charts-pie-features-py

labels = 'Female', 'Male'

#count the number of males and females
print("The number of females is: ",(tips.sex=='Female').sum())
print("The number of males is: ",(tips.sex=='Male').sum())

#use numbers obtained to create the pie chart
sizes = [87, 157]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # explode 1st slice

#Plot pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
